# %%
import pandas as pd

# %%
url = ('/Users/xhail/Downloads/Daily Power Generation/PowerGeneration.csv')

# %%
data = pd.read_csv(url)
data = data.drop_duplicates()

# %%
data[:100]
# Out:
#           Date Power Station  Monitored Cap.(MW)  \
# 0   01-09-2017         Delhi              2235.4
# 1   01-09-2017          STPL              1350.0
# 2   01-09-2017          SPPL               150.0
# 3   01-09-2017           SPL              3960.0
# 4   01-09-2017           SKS               600.0
# ..         ...           ...                 ...
# 95  01-09-2017         JITPL              1200.0
# 96  01-09-2017          ICCL                 0.0
# 97  01-09-2017         IBPIL               350.0
# 98  01-09-2017         NALCO                 0.0
# 99  01-09-2017       Manipur                36.0
#
#     Total Cap. Under Maintenace (MW)  Planned Maintanence (MW)  \
# 0                              135.0                       0.0
# 1                             1350.0                       0.0
# 2                              150.0                       0.0
# 3                                0.0                       0.0
# ...

# %%
unique_stations = data['Power Station'].unique().tolist()
unique_stations
# Out:
# ['Delhi',
#  'STPL',
#  'SPPL',
#  'SPL',
#  'SKS',
#  'SCPL',
#  'RKMPPL',
#  'RGPPL',
#  'SVPPL',
#  'RELIANCE',
#  'RATTANINDIA',
#  'PGPL',
#  'NTPC Ltd.',
#  'NSPCL',
#  'NPCIL',
#  'NHDC',
#  'MCCPL',
#  'REGL',
#  'MBPMPL',
#  'TATA MAH.',
#  'TOR. POW. (SUGEN)',
#  'BSES  AP',
#  'BELLARY',
#  'APGPCL',
#  'ABAN POWR',
#  'Telangana',
#  'Tamil Nadu',
#  'Puducherry',
#  'TATA PCL',
#  'Kerala',
#  'Andhra Pradesh',
#  'WPCL',
#  'VVL',
#  'VIP',
#  'VESPL',
#  'TRNE',
#  'TOR. POW. (UNOSUGEN)',
#  'Karnataka',
#  'LVTPL',
#  'LANCO',
#  'JSWEL',
#  'ACPL',
#  'ACB',
#  'Maharashtra',
#  'Madhya Pradesh',
#  'Gujarat',
#  'Chhatisgarh',
#  'TSPL',
#  'AEML',
#  'TPDDL',
#  'SrEPL',
#  'SJVNL',
#  'RWPL (JSW)',
#  'RPSCL',
#  'PPGCL (Jaypee)',
#  'NUPPL',
#  'THDC',
#  'AMNEPL',
#  'APL',
#  'BALCO',
#  'JPPVL',
#  'JPL',
#  'JHAPL',
#  'IEPL',
#  'GMR ENERG',
#  'GIPCL',
#  'GEPL',
#  'GCEL',
#  'ESSARPMPL',
#  'ESSAR',
#  'EPGL',
#  'DLHP',
#  'DIL',
#  'DBPCL',
# ...

# %%
power_gen = data.rename(columns = {'Power Station' : 'power_station', 'Monitored Cap.(MW)' : 'monitored_cap', 'Total Cap. Under Maintenace (MW)' : 'total_cap_under_maint', 'Planned Maintanence (MW)' : 'planned_maint', 'Forced Maintanence(MW)' : 'forced_maint', 'Other Reasons (MW)' : 'other_reasons', 'Programme (MW)' : 'programme', 'Actual (MW)' : 'actual', 'Excess(+) / Shortfall (-) (MW)' : 'excess_shortfall', 'Deviation (MW)' : 'deviation'})

# %%
data.head()
# Out:
#          Date Power Station  Monitored Cap.(MW)  \
# 0  01-09-2017         Delhi              2235.4
# 1  01-09-2017          STPL              1350.0
# 2  01-09-2017          SPPL               150.0
# 3  01-09-2017           SPL              3960.0
# 4  01-09-2017           SKS               600.0
#
#    Total Cap. Under Maintenace (MW)  Planned Maintanence (MW)  \
# 0                             135.0                       0.0
# 1                            1350.0                       0.0
# 2                             150.0                       0.0
# 3                               0.0                       0.0
# 4                             300.0                       0.0
#
#    Forced Maintanence(MW)  Other Reasons (MW)  Programme (MW)  Actual (MW)  \
# 0                   135.0                 0.0           13.29        18.29
# 1                  1350.0                 0.0            0.00         0.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 192884 entries, 0 to 334993
# Data columns (total 11 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Date                              192884 non-null  object
#  1   Power Station                     192884 non-null  object
#  2   Monitored Cap.(MW)                192884 non-null  float64
#  3   Total Cap. Under Maintenace (MW)  192884 non-null  float64
#  4   Planned Maintanence (MW)          192884 non-null  float64
#  5   Forced Maintanence(MW)            192884 non-null  float64
#  6   Other Reasons (MW)                192884 non-null  float64
#  7   Programme (MW)                    192884 non-null  float64
#  8   Actual (MW)                       192884 non-null  float64
#  9   Excess(+) / Shortfall (-) (MW)    192884 non-null  float64
#  10  Deviation (MW)                    192884 non-null  float64
# dtypes: float64(9), object(2)
# ...
